# %%
# Cell 1: Imports and Configuration
import os
import torch
import h5py
import numpy as np
import pandas as pd
import os.path as osp
import matplotlib.pyplot as plt
import optuna
from torch_geometric.data import Data, Dataset
from torch_geometric.nn import GCNConv, GATConv, knn_graph
import torch.nn.functional as F
from sklearn.metrics import accuracy_score

# Configuration
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
K = 15
EPOCHS = 200
PATIENCE = 10  # Early stopping patience
OPTUNA_TRIALS = 20  # Number of Optuna trials

# %%
# Cell 2: Dataset Class Definition
class MusicGraphDataset(Dataset):
    def __init__(self, root, metadata_path, features_path):
        self.metadata_path = metadata_path
        self.features_path = features_path
        super().__init__(root)
        
    @property
    def processed_file_names(self):
        return ['data.pt', 'norm_params.pt']
    
    def process(self):
        # Load metadata and features
        df = pd.read_csv(self.metadata_path)
        with h5py.File(self.features_path, 'r') as f:
            features = torch.tensor(np.array(f['features']), dtype=torch.float32)
            labels = torch.tensor(np.array(f['labels']), dtype=torch.long)
        
        # Create stratified splits
        indices = torch.randperm(len(features))
        train_idx = indices[:int(0.8*len(indices))]
        val_idx = indices[int(0.8*len(indices)):int(0.9*len(indices))]
        test_idx = indices[int(0.9*len(indices)):]

        # Normalization
        X_min = features[train_idx].min()
        X_max = features[train_idx].max()
        features = (features - X_min) / (X_max - X_min + 1e-8)

        # Create graph
        edge_index = knn_graph(features, k=K)

        # Create masks
        train_mask = torch.zeros(len(features), dtype=bool)
        val_mask = torch.zeros(len(features), dtype=bool)
        test_mask = torch.zeros(len(features), dtype=bool)
        train_mask[train_idx] = True
        val_mask[val_idx] = True
        test_mask[test_idx] = True

        data = Data(
            x=features,
            edge_index=edge_index,
            y=labels,
            train_mask=train_mask,
            val_mask=val_mask,
            test_mask=test_mask
        )

        # Save processed data
        torch.save(data, osp.join(self.processed_dir, 'data.pt'))
        torch.save({'min': X_min, 'max': X_max}, 
                 osp.join(self.processed_dir, 'norm_params.pt'))

# %%
# Cell 3: Model Definitions
class GCN(torch.nn.Module):
    def __init__(self, num_features, num_classes, hidden_dim, dropout):
        super().__init__()
        self.conv1 = GCNConv(num_features, hidden_dim)
        self.bn1 = torch.nn.BatchNorm1d(hidden_dim)
        self.conv2 = GCNConv(hidden_dim, num_classes)
        self.dropout = dropout

    def forward(self, x, edge_index):
        x = F.relu(self.bn1(self.conv1(x, edge_index)))
        x = F.dropout(x, p=self.dropout, training=self.training)
        x = self.conv2(x, edge_index)
        return F.log_softmax(x, dim=1)

class GAT(torch.nn.Module):
    def __init__(self, num_features, num_classes, hidden_dim, dropout, heads):
        super().__init__()
        self.conv1 = GATConv(num_features, hidden_dim, heads=heads)
        self.bn1 = torch.nn.BatchNorm1d(hidden_dim * heads)
        self.conv2 = GATConv(hidden_dim * heads, num_classes, heads=1, concat=False)
        self.dropout = dropout

    def forward(self, x, edge_index):
        x = F.relu(self.bn1(self.conv1(x, edge_index)))
        x = F.dropout(x, p=self.dropout, training=self.training)
        x = self.conv2(x, edge_index)
        return F.log_softmax(x, dim=1)

# %%
# Cell 2: Update Optuna Objective Function to Handle OOM
def objective(trial):
    try:
        # Hyperparameters to optimize
        hidden_dim = trial.suggest_int('hidden_dim', 16, 64)  # Reduced max hidden_dim
        dropout = trial.suggest_float('dropout', 0.2, 0.5)
        lr = trial.suggest_float('lr', 1e-4, 1e-2, log=True)
        weight_decay = trial.suggest_float('weight_decay', 1e-5, 1e-3, log=True)
        heads = trial.suggest_int('heads', 2, 4) if MODEL_TYPE == 'gat' else 1  # Reduced max heads

        # Initialize dataset
        dataset = MusicGraphDataset(
            root='processed_data',
            metadata_path='nepali_music_metadata.csv',
            features_path='nepali_features.hdf5'
        )
        data = torch.load(osp.join(dataset.processed_dir, 'data.pt')).to(DEVICE)

        # Initialize model
        if MODEL_TYPE == 'gcn':
            model = GCN(data.num_features, 10, hidden_dim, dropout).to(DEVICE)
        else:
            model = GAT(data.num_features, 10, hidden_dim, dropout, heads).to(DEVICE)

        # Optimizer and scheduler
        optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
        scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5)

        # Training loop
        best_val_loss = float('inf')
        for epoch in range(EPOCHS):
            model.train()
            optimizer.zero_grad()
            out = model(data.x, data.edge_index)
            loss = F.nll_loss(out[data.train_mask], data.y[data.train_mask])
            loss.backward()
            optimizer.step()

            # Validation
            model.eval()
            with torch.no_grad():
                out = model(data.x, data.edge_index)
                val_loss = F.nll_loss(out[data.val_mask], data.y[data.val_mask]).item()
                scheduler.step(val_loss)

                # Early stopping
                if val_loss < best_val_loss:
                    best_val_loss = val_loss
                    epochs_without_improvement = 0
                    # Save the best model
                    torch.save(model.state_dict(), f'best_{MODEL_TYPE}_trial_{trial.number}.pt')
                else:
                    epochs_without_improvement += 1
                    if epochs_without_improvement >= PATIENCE:
                        break

        # Clear memory
        del model, optimizer, scheduler
        torch.cuda.empty_cache()

        return best_val_loss

    except RuntimeError as e:
        if 'CUDA out of memory' in str(e):
            print(f"OOM error in trial {trial.number}. Skipping...")
            torch.cuda.empty_cache()
            return float('inf')  # Return a high loss to discard this trial
        else:
            raise e

# %%
# Cell 5: Run Optuna Optimization
def optimize_hyperparameters():
    study = optuna.create_study(direction='minimize')
    study.optimize(objective, n_trials=OPTUNA_TRIALS)

    # Save the best hyperparameters and model
    best_trial = study.best_trial
    print(f"Best trial: {best_trial.number}")
    print(f"Best validation loss: {best_trial.value:.4f}")
    print(f"Best hyperparameters: {best_trial.params}")

    # Rename the best model file
    best_model_path = f'best_{MODEL_TYPE}_trial_{best_trial.number}.pt'
    final_model_path = f'best_{MODEL_TYPE}.pt'
    os.rename(best_model_path, final_model_path)
    print(f"Best model saved to {final_model_path}")

# Run optimization for GCN
MODEL_TYPE = 'gcn'
optimize_hyperparameters()

# Run optimization for GAT
MODEL_TYPE = 'gat'
optimize_hyperparameters()
# Out:
# [I 2025-01-26 18:48:52,336] A new study created in memory with name: no-name-73f1fca0-485f-4d37-aa02-47f711cf4789
# /tmp/ipykernel_13251/2887968249.py:17: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(osp.join(dataset.processed_dir, 'data.pt')).to(DEVICE)
# [I 2025-01-26 18:48:53,274] Trial 0 finished with value: 0.6143243312835693 and parameters: {'hidden_dim': 32, 'dropout': 0.29105992951551224, 'lr': 0.001790924331699668, 'weight_decay': 0.00012570685241097726}. Best is trial 0 with value: 0.6143243312835693.
# [I 2025-01-26 18:48:54,269] Trial 1 finished with value: 0.6623527407646179 and parameters: {'hidden_dim': 33, 'dropout': 0.20996309036041805, 'lr': 0.0010709457838228014, 'weight_decay': 0.0004444924363065619}. Best is trial 0 with value: 0.6143243312835693.
# [I 2025-01-26 18:48:55,492] Trial 2 finished with value: 0.6279125809669495 and parameters: {'hidden_dim': 61, 'dropout': 0.2471971908382101, 'lr': 0.000542469796894435, 'weight_decay': 0.0002324185516903757}. Best is trial 0 with value: 0.6143243312835693.
# [I 2025-01-26 18:48:55,831] Trial 3 finished with value: 0.7397263050079346 and parameters: {'hidden_dim': 22, 'dropout': 0.3180489372961256, 'lr': 0.009820539847394805, 'weight_decay': 0.00017548666796022742}. Best is trial 0 with value: 0.6143243312835693.
# [I 2025-01-26 18:48:56,694] Trial 4 finished with value: 1.060072660446167 and parameters: {'hidden_dim': 24, 'dropout': 0.4606235762726407, 'lr': 0.00017915276128941524, 'weight_decay': 0.0003437876435296912}. Best is trial 0 with value: 0.6143243312835693.
# [I 2025-01-26 18:48:57,808] Trial 5 finished with value: 0.6976324319839478 and parameters: {'hidden_dim': 42, 'dropout': 0.20660367373584884, 'lr': 0.0004122282186460835, 'weight_decay': 0.00024051376424086065}. Best is trial 0 with value: 0.6143243312835693.
# [I 2025-01-26 18:48:58,841] Trial 6 finished with value: 0.6414408683776855 and parameters: {'hidden_dim': 39, 'dropout': 0.21904890534135263, 'lr': 0.0009316100675576406, 'weight_decay': 9.868696872446464e-05}. Best is trial 0 with value: 0.6143243312835693.
# [I 2025-01-26 18:48:59,660] Trial 7 finished with value: 0.7037867307662964 and parameters: {'hidden_dim': 23, 'dropout': 0.27084850624193557, 'lr': 0.0009502677567765474, 'weight_decay': 0.0001534050683931151}. Best is trial 0 with value: 0.6143243312835693.
# [I 2025-01-26 18:49:00,733] Trial 8 finished with value: 0.7631101608276367 and parameters: {'hidden_dim': 41, 'dropout': 0.4750867990120596, 'lr': 0.00033815257924991354, 'weight_decay': 3.660026338027364e-05}. Best is trial 0 with value: 0.6143243312835693.
# [I 2025-01-26 18:49:01,480] Trial 9 finished with value: 0.7660269141197205 and parameters: {'hidden_dim': 17, 'dropout': 0.45792784711952444, 'lr': 0.0012816215261044351, 'weight_decay': 0.0008265409657034388}. Best is trial 0 with value: 0.6143243312835693.
# [I 2025-01-26 18:49:02,509] Trial 10 finished with value: 0.6049627661705017 and parameters: {'hidden_dim': 54, 'dropout': 0.38565837300797307, 'lr': 0.0038306529379653707, 'weight_decay': 1.1382122378186038e-05}. Best is trial 10 with value: 0.6049627661705017.
# [I 2025-01-26 18:49:03,369] Trial 11 finished with value: 0.6101927757263184 and parameters: {'hidden_dim': 56, 'dropout': 0.38655999893847104, 'lr': 0.003881824249697799, 'weight_decay': 1.5015713423840704e-05}. Best is trial 10 with value: 0.6049627661705017.
# [I 2025-01-26 18:49:04,355] Trial 12 finished with value: 0.5906979441642761 and parameters: {'hidden_dim': 58, 'dropout': 0.38731863769700403, 'lr': 0.004521722556740031, 'weight_decay': 1.0924099937267597e-05}. Best is trial 12 with value: 0.5906979441642761.
# [I 2025-01-26 18:49:05,345] Trial 13 finished with value: 0.5919840335845947 and parameters: {'hidden_dim': 52, 'dropout': 0.3809073408172573, 'lr': 0.004576139706458489, 'weight_decay': 1.0450736925975057e-05}. Best is trial 12 with value: 0.5906979441642761.
# [I 2025-01-26 18:49:06,194] Trial 14 finished with value: 0.5887933969497681 and parameters: {'hidden_dim': 50, 'dropout': 0.39410414601592014, 'lr': 0.008996747315756962, 'weight_decay': 2.6701727056786464e-05}. Best is trial 14 with value: 0.5887933969497681.
# [I 2025-01-26 18:49:06,978] Trial 15 finished with value: 0.6452905535697937 and parameters: {'hidden_dim': 64, 'dropout': 0.43125587035003216, 'lr': 0.009892448024039852, 'weight_decay': 2.9913873837247156e-05}. Best is trial 14 with value: 0.5887933969497681.
# [I 2025-01-26 18:49:08,054] Trial 16 finished with value: 0.5535299777984619 and parameters: {'hidden_dim': 48, 'dropout': 0.35383540022461457, 'lr': 0.0059797792015148545, 'weight_decay': 3.398807978977328e-05}. Best is trial 16 with value: 0.5535299777984619.
# [I 2025-01-26 18:49:08,723] Trial 17 finished with value: 0.6563515067100525 and parameters: {'hidden_dim': 47, 'dropout': 0.3335585247689767, 'lr': 0.0021710315005500046, 'weight_decay': 5.74357739588969e-05}. Best is trial 16 with value: 0.5535299777984619.
# [I 2025-01-26 18:49:09,539] Trial 18 finished with value: 0.609474778175354 and parameters: {'hidden_dim': 49, 'dropout': 0.41851708053872794, 'lr': 0.006637118774650777, 'weight_decay': 2.4853607045850105e-05}. Best is trial 16 with value: 0.5535299777984619.
# [I 2025-01-26 18:49:10,628] Trial 19 finished with value: 0.584590494632721 and parameters: {'hidden_dim': 46, 'dropout': 0.35401246511091583, 'lr': 0.002188527285925532, 'weight_decay': 5.999618086398735e-05}. Best is trial 16 with value: 0.5535299777984619.
# [I 2025-01-26 18:49:10,629] A new study created in memory with name: no-name-8855cb04-0557-4d00-9fb2-469bcd4f8ec1
# Best trial: 16
# Best validation loss: 0.5535
# Best hyperparameters: {'hidden_dim': 48, 'dropout': 0.35383540022461457, 'lr': 0.0059797792015148545, 'weight_decay': 3.398807978977328e-05}
# Best model saved to best_gcn.pt
# [I 2025-01-26 18:49:13,033] Trial 0 finished with value: 0.607587993144989 and parameters: {'hidden_dim': 57, 'dropout': 0.4259367630594231, 'lr': 0.0006053020338365133, 'weight_decay': 1.0399241217255609e-05, 'heads': 2}. Best is trial 0 with value: 0.607587993144989.
# [I 2025-01-26 18:49:15,158] Trial 1 finished with value: 0.5707818865776062 and parameters: {'hidden_dim': 24, 'dropout': 0.341485248071941, 'lr': 0.0028413205322696086, 'weight_decay': 2.851478550278825e-05, 'heads': 4}. Best is trial 1 with value: 0.5707818865776062.
# [I 2025-01-26 18:49:16,595] Trial 2 finished with value: 0.6851847171783447 and parameters: {'hidden_dim': 41, 'dropout': 0.4302787721796704, 'lr': 0.0052244943442277736, 'weight_decay': 5.732077384602792e-05, 'heads': 4}. Best is trial 1 with value: 0.5707818865776062.
# [I 2025-01-26 18:49:19,215] Trial 3 finished with value: 0.6370624303817749 and parameters: {'hidden_dim': 42, 'dropout': 0.4449505888579305, 'lr': 0.00041850458787823756, 'weight_decay': 1.711948088003778e-05, 'heads': 3}. Best is trial 1 with value: 0.5707818865776062.
# [I 2025-01-26 18:49:21,685] Trial 4 finished with value: 0.7767782807350159 and parameters: {'hidden_dim': 28, 'dropout': 0.32122255173447123, 'lr': 0.00012187486644086673, 'weight_decay': 0.0006228140413404373, 'heads': 4}. Best is trial 1 with value: 0.5707818865776062.
# [I 2025-01-26 18:49:23,358] Trial 5 finished with value: 0.6642823219299316 and parameters: {'hidden_dim': 32, 'dropout': 0.25114736867816406, 'lr': 0.00040002000489759785, 'weight_decay': 0.0008452465788562798, 'heads': 2}. Best is trial 1 with value: 0.5707818865776062.
# [I 2025-01-26 18:49:25,821] Trial 6 finished with value: 0.7455114722251892 and parameters: {'hidden_dim': 27, 'dropout': 0.437645154166204, 'lr': 0.00017608620157945646, 'weight_decay': 0.0008793012944319574, 'heads': 4}. Best is trial 1 with value: 0.5707818865776062.
# [I 2025-01-26 18:49:28,335] Trial 7 finished with value: 0.5796806812286377 and parameters: {'hidden_dim': 57, 'dropout': 0.3412133150731459, 'lr': 0.0019653090385110678, 'weight_decay': 3.744928988492222e-05, 'heads': 3}. Best is trial 1 with value: 0.5707818865776062.
# [I 2025-01-26 18:49:30,017] Trial 8 finished with value: 0.6340363025665283 and parameters: {'hidden_dim': 21, 'dropout': 0.4672848933902601, 'lr': 0.0018146760073153296, 'weight_decay': 0.0007725714205896232, 'heads': 3}. Best is trial 1 with value: 0.5707818865776062.
# [I 2025-01-26 18:49:30,772] Trial 9 finished with value: 0.724650502204895 and parameters: {'hidden_dim': 16, 'dropout': 0.41681157822335246, 'lr': 0.004451741188131086, 'weight_decay': 0.00033216133909235693, 'heads': 4}. Best is trial 1 with value: 0.5707818865776062.
# [I 2025-01-26 18:49:32,522] Trial 10 finished with value: 0.6285120248794556 and parameters: {'hidden_dim': 36, 'dropout': 0.20080011941556852, 'lr': 0.008179361359994763, 'weight_decay': 0.00013679028118968674, 'heads': 4}. Best is trial 1 with value: 0.5707818865776062.
# [I 2025-01-26 18:49:34,252] Trial 11 finished with value: 0.6296414136886597 and parameters: {'hidden_dim': 63, 'dropout': 0.34163582172538404, 'lr': 0.0018884010429325272, 'weight_decay': 3.65752898925442e-05, 'heads': 3}. Best is trial 1 with value: 0.5707818865776062.
# [I 2025-01-26 18:49:36,042] Trial 12 finished with value: 0.6266037821769714 and parameters: {'hidden_dim': 52, 'dropout': 0.2946370644415358, 'lr': 0.001804136669826255, 'weight_decay': 3.10990723579554e-05, 'heads': 3}. Best is trial 1 with value: 0.5707818865776062.
# [I 2025-01-26 18:49:38,354] Trial 13 finished with value: 0.5734858512878418 and parameters: {'hidden_dim': 49, 'dropout': 0.3796948336088258, 'lr': 0.0030078894380154756, 'weight_decay': 0.00012945573005943248, 'heads': 3}. Best is trial 1 with value: 0.5707818865776062.
# [I 2025-01-26 18:49:40,469] Trial 14 finished with value: 0.5859651565551758 and parameters: {'hidden_dim': 46, 'dropout': 0.3867794020674889, 'lr': 0.003709219924768225, 'weight_decay': 0.00012634958588991438, 'heads': 2}. Best is trial 1 with value: 0.5707818865776062.
# [I 2025-01-26 18:49:42,416] Trial 15 finished with value: 0.6153875589370728 and parameters: {'hidden_dim': 49, 'dropout': 0.3785893877062536, 'lr': 0.0009235691959690221, 'weight_decay': 0.0002483170683196513, 'heads': 3}. Best is trial 1 with value: 0.5707818865776062.
# [I 2025-01-26 18:49:43,478] Trial 16 finished with value: 0.6842512488365173 and parameters: {'hidden_dim': 35, 'dropout': 0.4991535768028025, 'lr': 0.009806212396209516, 'weight_decay': 7.935207299612346e-05, 'heads': 3}. Best is trial 1 with value: 0.5707818865776062.
# [I 2025-01-26 18:49:44,790] Trial 17 finished with value: 0.644923210144043 and parameters: {'hidden_dim': 23, 'dropout': 0.2761427514393413, 'lr': 0.0030649920158137764, 'weight_decay': 0.0001998926521174615, 'heads': 4}. Best is trial 1 with value: 0.5707818865776062.
# [I 2025-01-26 18:49:46,391] Trial 18 finished with value: 0.6143048405647278 and parameters: {'hidden_dim': 45, 'dropout': 0.38419778262144033, 'lr': 0.0010632721363540319, 'weight_decay': 1.715262814669895e-05, 'heads': 2}. Best is trial 1 with value: 0.5707818865776062.
# [I 2025-01-26 18:49:48,211] Trial 19 finished with value: 0.6189230680465698 and parameters: {'hidden_dim': 53, 'dropout': 0.36591149608263496, 'lr': 0.006127396321263311, 'weight_decay': 6.15597877599459e-05, 'heads': 3}. Best is trial 1 with value: 0.5707818865776062.
# Best trial: 1
# Best validation loss: 0.5708
# Best hyperparameters: {'hidden_dim': 24, 'dropout': 0.341485248071941, 'lr': 0.0028413205322696086, 'weight_decay': 2.851478550278825e-05, 'heads': 4}
# Best model saved to best_gat.pt

# %%
# Cell 1: Imports and Configuration
import torch
import torch.nn.functional as F
from torch_geometric.nn import GCNConv, GATConv

# Configuration
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Best hyperparameters for GAT
GAT_HYPERPARAMS = {
    'hidden_dim': 24,
    'dropout': 0.341485248071941,
    'lr': 0.0028413205322696086,
    'weight_decay': 2.851478550278825e-05,
    'heads': 4
}

# Best hyperparameters for GCN
GCN_HYPERPARAMS = {
    'hidden_dim': 48,
    'dropout': 0.35383540022461457,
    'lr': 0.0059797792015148545,
    'weight_decay': 3.398807978977328e-05
}

# %%
# Cell 2: GAT Model
class GAT(torch.nn.Module):
    def __init__(self, num_features, num_classes):
        super().__init__()
        self.conv1 = GATConv(
            num_features,
            GAT_HYPERPARAMS['hidden_dim'],
            heads=GAT_HYPERPARAMS['heads']
        )
        self.bn1 = torch.nn.BatchNorm1d(GAT_HYPERPARAMS['hidden_dim'] * GAT_HYPERPARAMS['heads'])
        self.conv2 = GATConv(
            GAT_HYPERPARAMS['hidden_dim'] * GAT_HYPERPARAMS['heads'],
            num_classes,
            heads=1,
            concat=False
        )
        self.dropout = GAT_HYPERPARAMS['dropout']

    def forward(self, x, edge_index):
        x = F.relu(self.bn1(self.conv1(x, edge_index)))
        x = F.dropout(x, p=self.dropout, training=self.training)
        x = self.conv2(x, edge_index)
        return F.log_softmax(x, dim=1)

# %%
# Cell 3: GCN Model
class GCN(torch.nn.Module):
    def __init__(self, num_features, num_classes):
        super().__init__()
        self.conv1 = GCNConv(num_features, GCN_HYPERPARAMS['hidden_dim'])
        self.bn1 = torch.nn.BatchNorm1d(GCN_HYPERPARAMS['hidden_dim'])
        self.conv2 = GCNConv(GCN_HYPERPARAMS['hidden_dim'], num_classes)
        self.dropout = GCN_HYPERPARAMS['dropout']

    def forward(self, x, edge_index):
        x = F.relu(self.bn1(self.conv1(x, edge_index)))
        x = F.dropout(x, p=self.dropout, training=self.training)
        x = self.conv2(x, edge_index)
        return F.log_softmax(x, dim=1)

# %%
# Cell 1: Plot Training and Validation Curves
import matplotlib.pyplot as plt

def plot_training_curves(gat_results, gcn_results):
    # Unpack results
    gat_train_losses, gat_train_accs, gat_val_losses, gat_val_accs = gat_results
    gcn_train_losses, gcn_train_accs, gcn_val_losses, gcn_val_accs = gcn_results

    # Create figure
    plt.figure(figsize=(15, 6))

    # Plot Loss Curves
    plt.subplot(1, 2, 1)
    plt.plot(gat_train_losses, label='GAT Train Loss', color='blue', linestyle='-')
    plt.plot(gat_val_losses, label='GAT Val Loss', color='blue', linestyle='--')
    plt.plot(gcn_train_losses, label='GCN Train Loss', color='orange', linestyle='-')
    plt.plot(gcn_val_losses, label='GCN Val Loss', color='orange', linestyle='--')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)

    # Plot Accuracy Curves
    plt.subplot(1, 2, 2)
    plt.plot(gat_train_accs, label='GAT Train Acc', color='blue', linestyle='-')
    plt.plot(gat_val_accs, label='GAT Val Acc', color='blue', linestyle='--')
    plt.plot(gcn_train_accs, label='GCN Train Acc', color='orange', linestyle='-')
    plt.plot(gcn_val_accs, label='GCN Val Acc', color='orange', linestyle='--')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    plt.show()

# %%
# Cell 2: Updated Training Function
def train_model(model, data, optimizer, scheduler):
    train_losses, val_losses = [], []
    train_accs, val_accs = [], []
    best_val_loss = float('inf')

    for epoch in range(EPOCHS):
        # Training
        model.train()
        optimizer.zero_grad()
        out = model(data.x, data.edge_index)
        loss = F.nll_loss(out[data.train_mask], data.y[data.train_mask])
        loss.backward()
        optimizer.step()

        # Training metrics
        pred = out[data.train_mask].argmax(dim=1)
        train_acc = (pred == data.y[data.train_mask]).float().mean().item()
        train_losses.append(loss.item())
        train_accs.append(train_acc)

        # Validation
        model.eval()
        with torch.no_grad():
            out = model(data.x, data.edge_index)
            val_loss = F.nll_loss(out[data.val_mask], data.y[data.val_mask]).item()
            pred_val = out[data.val_mask].argmax(dim=1)
            val_acc = (pred_val == data.y[data.val_mask]).float().mean().item()
            val_losses.append(val_loss)
            val_accs.append(val_acc)

            # Save best model
            if val_loss < best_val_loss:
                best_val_loss = val_loss
                torch.save(model.state_dict(), f'best_{model.__class__.__name__}.pt')

        # Step the scheduler
        if scheduler:
            scheduler.step(val_loss)

        print(f'Epoch {epoch + 1:03d} | '
              f'Train Loss: {loss.item():.4f} | Train Acc: {train_acc:.4f} | '
              f'Val Loss: {val_loss:.4f} | Val Acc: {val_acc:.4f}')

    return train_losses, train_accs, val_losses, val_accs

# %%
# Cell 1: Merged Function to Train, Save, and Plot
def train_save_and_plot():
    # Initialize dataset
    dataset = MusicGraphDataset(
        root='all_graph_data',  # Use the correct root directory
        metadata_path='nepali_music_metadata.csv',
        features_path='nepali_features.hdf5'
    )
    data = torch.load(osp.join(dataset.processed_dir, 'data.pt')).to(DEVICE)

    # Train GAT
    print("Training GAT with best hyperparameters...")
    gat_model = GAT(data.num_features, 10).to(DEVICE)
    gat_optimizer = torch.optim.Adam(
        gat_model.parameters(),
        lr=GAT_HYPERPARAMS['lr'],
        weight_decay=GAT_HYPERPARAMS['weight_decay']
    )
    gat_scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(gat_optimizer, mode='min', factor=0.5, patience=5)
    gat_results = train_model(gat_model, data, gat_optimizer, gat_scheduler)

    # Save best GAT model
    torch.save(gat_model.state_dict(), 'best_GAT.pt')
    print("Best GAT model saved to 'best_GAT.pt'")

    # Train GCN
    print("Training GCN with best hyperparameters...")
    gcn_model = GCN(data.num_features, 10).to(DEVICE)
    gcn_optimizer = torch.optim.Adam(
        gcn_model.parameters(),
        lr=GCN_HYPERPARAMS['lr'],
        weight_decay=GCN_HYPERPARAMS['weight_decay']
    )
    gcn_scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(gcn_optimizer, mode='min', factor=0.5, patience=5)
    gcn_results = train_model(gcn_model, data, gcn_optimizer, gcn_scheduler)

    # Save best GCN model
    torch.save(gcn_model.state_dict(), 'best_GCN.pt')
    print("Best GCN model saved to 'best_GCN.pt'")

    # Plot results
    plot_training_curves(gat_results, gcn_results)

# %%
# Run training, saving, and plotting
train_save_and_plot()
# Out:
# /tmp/ipykernel_13251/1956463193.py:9: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(osp.join(dataset.processed_dir, 'data.pt')).to(DEVICE)
# Training GAT with best hyperparameters...
# Epoch 001 | Train Loss: 2.6403 | Train Acc: 0.0829 | Val Loss: 2.2970 | Val Acc: 0.2114
# Epoch 002 | Train Loss: 2.1786 | Train Acc: 0.2677 | Val Loss: 2.2837 | Val Acc: 0.3595
# Epoch 003 | Train Loss: 1.9629 | Train Acc: 0.4351 | Val Loss: 2.2695 | Val Acc: 0.3893
# Epoch 004 | Train Loss: 1.8071 | Train Acc: 0.5127 | Val Loss: 2.2581 | Val Acc: 0.4328
# Epoch 005 | Train Loss: 1.6760 | Train Acc: 0.5310 | Val Loss: 2.2372 | Val Acc: 0.4776
# Epoch 006 | Train Loss: 1.5885 | Train Acc: 0.5609 | Val Loss: 2.2172 | Val Acc: 0.5087
# Epoch 007 | Train Loss: 1.5561 | Train Acc: 0.5631 | Val Loss: 2.1964 | Val Acc: 0.5261
# Epoch 008 | Train Loss: 1.4798 | Train Acc: 0.5796 | Val Loss: 2.1746 | Val Acc: 0.5473
# Epoch 009 | Train Loss: 1.4280 | Train Acc: 0.5797 | Val Loss: 2.1536 | Val Acc: 0.5709
# Epoch 010 | Train Loss: 1.3583 | Train Acc: 0.5957 | Val Loss: 2.1332 | Val Acc: 0.5808
# Epoch 011 | Train Loss: 1.3506 | Train Acc: 0.6004 | Val Loss: 2.1068 | Val Acc: 0.5970
# Epoch 012 | Train Loss: 1.2908 | Train Acc: 0.6250 | Val Loss: 2.0777 | Val Acc: 0.6007
# Epoch 013 | Train Loss: 1.2866 | Train Acc: 0.6194 | Val Loss: 2.0480 | Val Acc: 0.6082
# Epoch 014 | Train Loss: 1.2405 | Train Acc: 0.6296 | Val Loss: 2.0225 | Val Acc: 0.6157
# Epoch 015 | Train Loss: 1.2044 | Train Acc: 0.6334 | Val Loss: 1.9969 | Val Acc: 0.6194
# Epoch 016 | Train Loss: 1.2063 | Train Acc: 0.6440 | Val Loss: 1.9700 | Val Acc: 0.6269
# Epoch 017 | Train Loss: 1.1848 | Train Acc: 0.6548 | Val Loss: 1.9430 | Val Acc: 0.6281
# Epoch 018 | Train Loss: 1.1405 | Train Acc: 0.6631 | Val Loss: 1.9161 | Val Acc: 0.6306
# Epoch 019 | Train Loss: 1.1257 | Train Acc: 0.6676 | Val Loss: 1.8879 | Val Acc: 0.6368
# Epoch 020 | Train Loss: 1.1025 | Train Acc: 0.6704 | Val Loss: 1.8596 | Val Acc: 0.6418
# Epoch 021 | Train Loss: 1.0771 | Train Acc: 0.6721 | Val Loss: 1.8270 | Val Acc: 0.6530
# Epoch 022 | Train Loss: 1.0503 | Train Acc: 0.6791 | Val Loss: 1.7965 | Val Acc: 0.6555
# Epoch 023 | Train Loss: 1.0574 | Train Acc: 0.6785 | Val Loss: 1.7630 | Val Acc: 0.6629
# Epoch 024 | Train Loss: 1.0422 | Train Acc: 0.6853 | Val Loss: 1.7345 | Val Acc: 0.6592
# Epoch 025 | Train Loss: 1.0181 | Train Acc: 0.6920 | Val Loss: 1.7068 | Val Acc: 0.6542
# Epoch 026 | Train Loss: 0.9974 | Train Acc: 0.6919 | Val Loss: 1.6804 | Val Acc: 0.6567
# Epoch 027 | Train Loss: 0.9934 | Train Acc: 0.6978 | Val Loss: 1.6491 | Val Acc: 0.6580
# Epoch 028 | Train Loss: 0.9984 | Train Acc: 0.6908 | Val Loss: 1.6171 | Val Acc: 0.6617
# Epoch 029 | Train Loss: 0.9812 | Train Acc: 0.6922 | Val Loss: 1.5831 | Val Acc: 0.6766
# Epoch 030 | Train Loss: 0.9735 | Train Acc: 0.7020 | Val Loss: 1.5513 | Val Acc: 0.6779
# Epoch 031 | Train Loss: 0.9563 | Train Acc: 0.7066 | Val Loss: 1.5154 | Val Acc: 0.6791
# Epoch 032 | Train Loss: 0.9456 | Train Acc: 0.7107 | Val Loss: 1.4818 | Val Acc: 0.6915
# Epoch 033 | Train Loss: 0.9277 | Train Acc: 0.7127 | Val Loss: 1.4486 | Val Acc: 0.6990
# Epoch 034 | Train Loss: 0.9173 | Train Acc: 0.7234 | Val Loss: 1.4133 | Val Acc: 0.7077
# Epoch 035 | Train Loss: 0.9274 | Train Acc: 0.7147 | Val Loss: 1.3802 | Val Acc: 0.7127
# Epoch 036 | Train Loss: 0.9201 | Train Acc: 0.7149 | Val Loss: 1.3545 | Val Acc: 0.7114
# Epoch 037 | Train Loss: 0.8936 | Train Acc: 0.7258 | Val Loss: 1.3274 | Val Acc: 0.7114
# Epoch 038 | Train Loss: 0.8955 | Train Acc: 0.7289 | Val Loss: 1.3003 | Val Acc: 0.7264
# Epoch 039 | Train Loss: 0.8740 | Train Acc: 0.7320 | Val Loss: 1.2772 | Val Acc: 0.7152
# Epoch 040 | Train Loss: 0.8895 | Train Acc: 0.7255 | Val Loss: 1.2493 | Val Acc: 0.7338
# Epoch 041 | Train Loss: 0.8797 | Train Acc: 0.7281 | Val Loss: 1.2212 | Val Acc: 0.7400
# Epoch 042 | Train Loss: 0.8554 | Train Acc: 0.7412 | Val Loss: 1.1900 | Val Acc: 0.7425
# Epoch 043 | Train Loss: 0.8550 | Train Acc: 0.7421 | Val Loss: 1.1645 | Val Acc: 0.7351
# Epoch 044 | Train Loss: 0.8450 | Train Acc: 0.7458 | Val Loss: 1.1419 | Val Acc: 0.7438
# Epoch 045 | Train Loss: 0.8519 | Train Acc: 0.7490 | Val Loss: 1.1170 | Val Acc: 0.7463
# Epoch 046 | Train Loss: 0.8393 | Train Acc: 0.7460 | Val Loss: 1.0877 | Val Acc: 0.7475
# Epoch 047 | Train Loss: 0.8292 | Train Acc: 0.7451 | Val Loss: 1.0621 | Val Acc: 0.7475
# Epoch 048 | Train Loss: 0.8218 | Train Acc: 0.7503 | Val Loss: 1.0440 | Val Acc: 0.7400
# Epoch 049 | Train Loss: 0.8247 | Train Acc: 0.7528 | Val Loss: 1.0194 | Val Acc: 0.7438
# Epoch 050 | Train Loss: 0.7979 | Train Acc: 0.7556 | Val Loss: 0.9951 | Val Acc: 0.7425
# Epoch 051 | Train Loss: 0.8002 | Train Acc: 0.7544 | Val Loss: 0.9981 | Val Acc: 0.7376
# Epoch 052 | Train Loss: 0.7935 | Train Acc: 0.7491 | Val Loss: 0.9776 | Val Acc: 0.7463
# Epoch 053 | Train Loss: 0.7862 | Train Acc: 0.7611 | Val Loss: 0.9615 | Val Acc: 0.7475
# Epoch 054 | Train Loss: 0.7836 | Train Acc: 0.7587 | Val Loss: 0.9446 | Val Acc: 0.7488
# Epoch 055 | Train Loss: 0.7984 | Train Acc: 0.7516 | Val Loss: 0.9306 | Val Acc: 0.7488
# Epoch 056 | Train Loss: 0.7704 | Train Acc: 0.7605 | Val Loss: 0.9380 | Val Acc: 0.7450
# Epoch 057 | Train Loss: 0.8118 | Train Acc: 0.7573 | Val Loss: 0.8990 | Val Acc: 0.7550
# Epoch 058 | Train Loss: 0.7716 | Train Acc: 0.7619 | Val Loss: 0.9027 | Val Acc: 0.7450
# Epoch 059 | Train Loss: 0.7786 | Train Acc: 0.7611 | Val Loss: 0.8834 | Val Acc: 0.7512
# Epoch 060 | Train Loss: 0.7630 | Train Acc: 0.7682 | Val Loss: 0.8804 | Val Acc: 0.7600
# Epoch 061 | Train Loss: 0.7708 | Train Acc: 0.7671 | Val Loss: 0.8652 | Val Acc: 0.7662
# Epoch 062 | Train Loss: 0.7597 | Train Acc: 0.7682 | Val Loss: 0.8521 | Val Acc: 0.7612
# Epoch 063 | Train Loss: 0.7481 | Train Acc: 0.7693 | Val Loss: 0.8624 | Val Acc: 0.7500
# Epoch 064 | Train Loss: 0.7624 | Train Acc: 0.7699 | Val Loss: 0.8351 | Val Acc: 0.7575
# Epoch 065 | Train Loss: 0.7573 | Train Acc: 0.7647 | Val Loss: 0.8310 | Val Acc: 0.7575
# Epoch 066 | Train Loss: 0.7561 | Train Acc: 0.7703 | Val Loss: 0.8344 | Val Acc: 0.7537
# Epoch 067 | Train Loss: 0.7492 | Train Acc: 0.7682 | Val Loss: 0.8257 | Val Acc: 0.7575
# Epoch 068 | Train Loss: 0.7604 | Train Acc: 0.7685 | Val Loss: 0.8399 | Val Acc: 0.7413
# Epoch 069 | Train Loss: 0.7491 | Train Acc: 0.7673 | Val Loss: 0.8773 | Val Acc: 0.7338
# Epoch 070 | Train Loss: 0.7478 | Train Acc: 0.7661 | Val Loss: 0.8565 | Val Acc: 0.7376
# Epoch 071 | Train Loss: 0.7430 | Train Acc: 0.7704 | Val Loss: 0.8383 | Val Acc: 0.7413
# Epoch 072 | Train Loss: 0.7502 | Train Acc: 0.7699 | Val Loss: 0.8386 | Val Acc: 0.7438
# Epoch 073 | Train Loss: 0.7509 | Train Acc: 0.7751 | Val Loss: 0.8456 | Val Acc: 0.7450
# Epoch 074 | Train Loss: 0.7411 | Train Acc: 0.7721 | Val Loss: 0.8185 | Val Acc: 0.7475
# Epoch 075 | Train Loss: 0.7248 | Train Acc: 0.7802 | Val Loss: 0.8025 | Val Acc: 0.7612
# Epoch 076 | Train Loss: 0.7216 | Train Acc: 0.7746 | Val Loss: 0.8073 | Val Acc: 0.7624
# Epoch 077 | Train Loss: 0.7385 | Train Acc: 0.7710 | Val Loss: 0.7980 | Val Acc: 0.7649
# Epoch 078 | Train Loss: 0.7167 | Train Acc: 0.7801 | Val Loss: 0.7959 | Val Acc: 0.7637
# Epoch 079 | Train Loss: 0.7109 | Train Acc: 0.7805 | Val Loss: 0.7921 | Val Acc: 0.7612
# Epoch 080 | Train Loss: 0.7251 | Train Acc: 0.7799 | Val Loss: 0.7806 | Val Acc: 0.7649
# Epoch 081 | Train Loss: 0.7100 | Train Acc: 0.7791 | Val Loss: 0.7814 | Val Acc: 0.7624
# Epoch 082 | Train Loss: 0.7180 | Train Acc: 0.7799 | Val Loss: 0.7722 | Val Acc: 0.7662
# Epoch 083 | Train Loss: 0.7167 | Train Acc: 0.7776 | Val Loss: 0.7597 | Val Acc: 0.7674
# Epoch 084 | Train Loss: 0.7006 | Train Acc: 0.7844 | Val Loss: 0.7622 | Val Acc: 0.7649
# Epoch 085 | Train Loss: 0.6971 | Train Acc: 0.7829 | Val Loss: 0.7711 | Val Acc: 0.7662
# Epoch 086 | Train Loss: 0.6969 | Train Acc: 0.7822 | Val Loss: 0.7642 | Val Acc: 0.7624
# Epoch 087 | Train Loss: 0.6906 | Train Acc: 0.7829 | Val Loss: 0.7581 | Val Acc: 0.7649
# Epoch 088 | Train Loss: 0.6838 | Train Acc: 0.7835 | Val Loss: 0.7546 | Val Acc: 0.7687
# Epoch 089 | Train Loss: 0.7030 | Train Acc: 0.7807 | Val Loss: 0.7602 | Val Acc: 0.7674
# Epoch 090 | Train Loss: 0.6998 | Train Acc: 0.7832 | Val Loss: 0.7652 | Val Acc: 0.7624
# Epoch 091 | Train Loss: 0.6903 | Train Acc: 0.7833 | Val Loss: 0.7591 | Val Acc: 0.7649
# Epoch 092 | Train Loss: 0.6905 | Train Acc: 0.7839 | Val Loss: 0.7497 | Val Acc: 0.7711
# Epoch 093 | Train Loss: 0.6828 | Train Acc: 0.7877 | Val Loss: 0.7449 | Val Acc: 0.7711
# Epoch 094 | Train Loss: 0.6769 | Train Acc: 0.7906 | Val Loss: 0.7495 | Val Acc: 0.7687
# Epoch 095 | Train Loss: 0.6833 | Train Acc: 0.7815 | Val Loss: 0.7403 | Val Acc: 0.7711
# Epoch 096 | Train Loss: 0.6707 | Train Acc: 0.7846 | Val Loss: 0.7427 | Val Acc: 0.7699
# Epoch 097 | Train Loss: 0.6855 | Train Acc: 0.7855 | Val Loss: 0.7357 | Val Acc: 0.7736
# Epoch 098 | Train Loss: 0.6760 | Train Acc: 0.7880 | Val Loss: 0.7380 | Val Acc: 0.7736
# Epoch 099 | Train Loss: 0.6802 | Train Acc: 0.7880 | Val Loss: 0.7393 | Val Acc: 0.7749
# Epoch 100 | Train Loss: 0.6750 | Train Acc: 0.7909 | Val Loss: 0.7350 | Val Acc: 0.7749
# Epoch 101 | Train Loss: 0.6680 | Train Acc: 0.7889 | Val Loss: 0.7221 | Val Acc: 0.7836
# Epoch 102 | Train Loss: 0.6606 | Train Acc: 0.7895 | Val Loss: 0.7208 | Val Acc: 0.7811
# Epoch 103 | Train Loss: 0.6780 | Train Acc: 0.7821 | Val Loss: 0.7204 | Val Acc: 0.7811
# Epoch 104 | Train Loss: 0.6604 | Train Acc: 0.7914 | Val Loss: 0.7241 | Val Acc: 0.7749
# Epoch 105 | Train Loss: 0.6564 | Train Acc: 0.7911 | Val Loss: 0.7251 | Val Acc: 0.7749
# Epoch 106 | Train Loss: 0.6583 | Train Acc: 0.7934 | Val Loss: 0.7216 | Val Acc: 0.7749
# Epoch 107 | Train Loss: 0.6516 | Train Acc: 0.7889 | Val Loss: 0.7202 | Val Acc: 0.7774
# Epoch 108 | Train Loss: 0.6623 | Train Acc: 0.7897 | Val Loss: 0.7153 | Val Acc: 0.7774
# Epoch 109 | Train Loss: 0.6545 | Train Acc: 0.7927 | Val Loss: 0.7297 | Val Acc: 0.7774
# Epoch 110 | Train Loss: 0.6639 | Train Acc: 0.7900 | Val Loss: 0.7187 | Val Acc: 0.7761
# Epoch 111 | Train Loss: 0.6606 | Train Acc: 0.7931 | Val Loss: 0.7127 | Val Acc: 0.7749
# Epoch 112 | Train Loss: 0.6531 | Train Acc: 0.7928 | Val Loss: 0.7207 | Val Acc: 0.7761
# Epoch 113 | Train Loss: 0.6537 | Train Acc: 0.7942 | Val Loss: 0.7169 | Val Acc: 0.7736
# Epoch 114 | Train Loss: 0.6550 | Train Acc: 0.7920 | Val Loss: 0.7137 | Val Acc: 0.7711
# Epoch 115 | Train Loss: 0.6435 | Train Acc: 0.7947 | Val Loss: 0.7204 | Val Acc: 0.7637
# Epoch 116 | Train Loss: 0.6563 | Train Acc: 0.7916 | Val Loss: 0.7128 | Val Acc: 0.7649
# Epoch 117 | Train Loss: 0.6554 | Train Acc: 0.7894 | Val Loss: 0.7052 | Val Acc: 0.7687
# Epoch 118 | Train Loss: 0.6441 | Train Acc: 0.7953 | Val Loss: 0.7059 | Val Acc: 0.7736
# Epoch 119 | Train Loss: 0.6409 | Train Acc: 0.7942 | Val Loss: 0.7110 | Val Acc: 0.7761
# Epoch 120 | Train Loss: 0.6499 | Train Acc: 0.7906 | Val Loss: 0.7287 | Val Acc: 0.7724
# Epoch 121 | Train Loss: 0.6526 | Train Acc: 0.7937 | Val Loss: 0.6998 | Val Acc: 0.7761
# Epoch 122 | Train Loss: 0.6432 | Train Acc: 0.7967 | Val Loss: 0.6995 | Val Acc: 0.7811
# Epoch 123 | Train Loss: 0.6495 | Train Acc: 0.7917 | Val Loss: 0.7019 | Val Acc: 0.7774
# Epoch 124 | Train Loss: 0.6373 | Train Acc: 0.7979 | Val Loss: 0.7164 | Val Acc: 0.7786
# Epoch 125 | Train Loss: 0.6402 | Train Acc: 0.7905 | Val Loss: 0.7063 | Val Acc: 0.7873
# Epoch 126 | Train Loss: 0.6390 | Train Acc: 0.8007 | Val Loss: 0.7052 | Val Acc: 0.7823
# Epoch 127 | Train Loss: 0.6448 | Train Acc: 0.7958 | Val Loss: 0.6988 | Val Acc: 0.7836
# Epoch 128 | Train Loss: 0.6326 | Train Acc: 0.7964 | Val Loss: 0.6966 | Val Acc: 0.7799
# Epoch 129 | Train Loss: 0.6338 | Train Acc: 0.7956 | Val Loss: 0.6949 | Val Acc: 0.7811
# Epoch 130 | Train Loss: 0.6297 | Train Acc: 0.7937 | Val Loss: 0.6980 | Val Acc: 0.7848
# Epoch 131 | Train Loss: 0.6307 | Train Acc: 0.8014 | Val Loss: 0.7094 | Val Acc: 0.7823
# Epoch 132 | Train Loss: 0.6345 | Train Acc: 0.7970 | Val Loss: 0.6876 | Val Acc: 0.7799
# Epoch 133 | Train Loss: 0.6366 | Train Acc: 0.7948 | Val Loss: 0.6994 | Val Acc: 0.7836
# Epoch 134 | Train Loss: 0.6352 | Train Acc: 0.7993 | Val Loss: 0.7041 | Val Acc: 0.7799
# Epoch 135 | Train Loss: 0.6332 | Train Acc: 0.7998 | Val Loss: 0.7006 | Val Acc: 0.7811
# Epoch 136 | Train Loss: 0.6246 | Train Acc: 0.8034 | Val Loss: 0.6946 | Val Acc: 0.7873
# Epoch 137 | Train Loss: 0.6294 | Train Acc: 0.8018 | Val Loss: 0.6905 | Val Acc: 0.7836
# Epoch 138 | Train Loss: 0.6228 | Train Acc: 0.8018 | Val Loss: 0.6837 | Val Acc: 0.7910
# Epoch 139 | Train Loss: 0.6349 | Train Acc: 0.8032 | Val Loss: 0.6951 | Val Acc: 0.7823
# Epoch 140 | Train Loss: 0.6223 | Train Acc: 0.8045 | Val Loss: 0.6981 | Val Acc: 0.7861
# Epoch 141 | Train Loss: 0.6358 | Train Acc: 0.8011 | Val Loss: 0.7092 | Val Acc: 0.7799
# Epoch 142 | Train Loss: 0.6334 | Train Acc: 0.8032 | Val Loss: 0.6905 | Val Acc: 0.7861
# Epoch 143 | Train Loss: 0.6275 | Train Acc: 0.7983 | Val Loss: 0.6887 | Val Acc: 0.7923
# Epoch 144 | Train Loss: 0.6333 | Train Acc: 0.8053 | Val Loss: 0.6870 | Val Acc: 0.7886
# Epoch 145 | Train Loss: 0.6356 | Train Acc: 0.8026 | Val Loss: 0.6846 | Val Acc: 0.7873
# Epoch 146 | Train Loss: 0.6293 | Train Acc: 0.8025 | Val Loss: 0.6935 | Val Acc: 0.7823
# Epoch 147 | Train Loss: 0.6415 | Train Acc: 0.7990 | Val Loss: 0.6888 | Val Acc: 0.7836
# Epoch 148 | Train Loss: 0.6229 | Train Acc: 0.8056 | Val Loss: 0.6880 | Val Acc: 0.7873
# Epoch 149 | Train Loss: 0.6238 | Train Acc: 0.8001 | Val Loss: 0.6780 | Val Acc: 0.7898
# Epoch 150 | Train Loss: 0.6183 | Train Acc: 0.8032 | Val Loss: 0.6803 | Val Acc: 0.7873
# Epoch 151 | Train Loss: 0.6227 | Train Acc: 0.8015 | Val Loss: 0.6832 | Val Acc: 0.7848
# Epoch 152 | Train Loss: 0.6143 | Train Acc: 0.8032 | Val Loss: 0.6949 | Val Acc: 0.7873
# Epoch 153 | Train Loss: 0.6241 | Train Acc: 0.8023 | Val Loss: 0.6856 | Val Acc: 0.7910
# Epoch 154 | Train Loss: 0.6214 | Train Acc: 0.7983 | Val Loss: 0.6817 | Val Acc: 0.7948
# Epoch 155 | Train Loss: 0.6144 | Train Acc: 0.8040 | Val Loss: 0.6774 | Val Acc: 0.7935
# Epoch 156 | Train Loss: 0.6147 | Train Acc: 0.8009 | Val Loss: 0.6736 | Val Acc: 0.7935
# Epoch 157 | Train Loss: 0.6107 | Train Acc: 0.8042 | Val Loss: 0.6790 | Val Acc: 0.7836
# Epoch 158 | Train Loss: 0.6098 | Train Acc: 0.8021 | Val Loss: 0.6811 | Val Acc: 0.7836
# Epoch 159 | Train Loss: 0.6066 | Train Acc: 0.8032 | Val Loss: 0.6803 | Val Acc: 0.7886
# Epoch 160 | Train Loss: 0.6182 | Train Acc: 0.7959 | Val Loss: 0.6729 | Val Acc: 0.7960
# Epoch 161 | Train Loss: 0.6052 | Train Acc: 0.8071 | Val Loss: 0.6696 | Val Acc: 0.7998
# Epoch 162 | Train Loss: 0.6100 | Train Acc: 0.8057 | Val Loss: 0.6696 | Val Acc: 0.7948
# Epoch 163 | Train Loss: 0.6057 | Train Acc: 0.8115 | Val Loss: 0.6694 | Val Acc: 0.7935
# Epoch 164 | Train Loss: 0.5955 | Train Acc: 0.8085 | Val Loss: 0.6711 | Val Acc: 0.7886
# Epoch 165 | Train Loss: 0.6010 | Train Acc: 0.8040 | Val Loss: 0.6631 | Val Acc: 0.7898
# Epoch 166 | Train Loss: 0.5915 | Train Acc: 0.8087 | Val Loss: 0.6604 | Val Acc: 0.7960
# Epoch 167 | Train Loss: 0.5919 | Train Acc: 0.8087 | Val Loss: 0.6635 | Val Acc: 0.7886
# Epoch 168 | Train Loss: 0.5989 | Train Acc: 0.8081 | Val Loss: 0.6611 | Val Acc: 0.7910
# Epoch 169 | Train Loss: 0.5950 | Train Acc: 0.8082 | Val Loss: 0.6603 | Val Acc: 0.7973
# Epoch 170 | Train Loss: 0.5919 | Train Acc: 0.8102 | Val Loss: 0.6589 | Val Acc: 0.7910
# Epoch 171 | Train Loss: 0.5936 | Train Acc: 0.8090 | Val Loss: 0.6544 | Val Acc: 0.7948
# Epoch 172 | Train Loss: 0.5977 | Train Acc: 0.8071 | Val Loss: 0.6546 | Val Acc: 0.7998
# Epoch 173 | Train Loss: 0.5892 | Train Acc: 0.8081 | Val Loss: 0.6570 | Val Acc: 0.7973
# Epoch 174 | Train Loss: 0.5888 | Train Acc: 0.8067 | Val Loss: 0.6624 | Val Acc: 0.7973
# Epoch 175 | Train Loss: 0.5859 | Train Acc: 0.8074 | Val Loss: 0.6732 | Val Acc: 0.7898
# Epoch 176 | Train Loss: 0.6037 | Train Acc: 0.8105 | Val Loss: 0.6577 | Val Acc: 0.7886
# Epoch 177 | Train Loss: 0.5838 | Train Acc: 0.8130 | Val Loss: 0.6548 | Val Acc: 0.7923
# Epoch 178 | Train Loss: 0.5832 | Train Acc: 0.8115 | Val Loss: 0.6539 | Val Acc: 0.7923
# Epoch 179 | Train Loss: 0.5890 | Train Acc: 0.8146 | Val Loss: 0.6529 | Val Acc: 0.7960
# Epoch 180 | Train Loss: 0.5863 | Train Acc: 0.8099 | Val Loss: 0.6536 | Val Acc: 0.7973
# Epoch 181 | Train Loss: 0.5884 | Train Acc: 0.8076 | Val Loss: 0.6601 | Val Acc: 0.7960
# Epoch 182 | Train Loss: 0.5844 | Train Acc: 0.8116 | Val Loss: 0.6658 | Val Acc: 0.7948
# Epoch 183 | Train Loss: 0.5802 | Train Acc: 0.8115 | Val Loss: 0.6589 | Val Acc: 0.7985
# Epoch 184 | Train Loss: 0.5822 | Train Acc: 0.8119 | Val Loss: 0.6546 | Val Acc: 0.8047
# Epoch 185 | Train Loss: 0.5830 | Train Acc: 0.8119 | Val Loss: 0.6513 | Val Acc: 0.7998
# Epoch 186 | Train Loss: 0.5711 | Train Acc: 0.8144 | Val Loss: 0.6489 | Val Acc: 0.8022
# Epoch 187 | Train Loss: 0.5781 | Train Acc: 0.8105 | Val Loss: 0.6468 | Val Acc: 0.8060
# Epoch 188 | Train Loss: 0.5768 | Train Acc: 0.8119 | Val Loss: 0.6453 | Val Acc: 0.8022
# Epoch 189 | Train Loss: 0.5733 | Train Acc: 0.8194 | Val Loss: 0.6453 | Val Acc: 0.8035
# Epoch 190 | Train Loss: 0.5800 | Train Acc: 0.8123 | Val Loss: 0.6479 | Val Acc: 0.8035
# Epoch 191 | Train Loss: 0.5803 | Train Acc: 0.8140 | Val Loss: 0.6504 | Val Acc: 0.8035
# Epoch 192 | Train Loss: 0.5790 | Train Acc: 0.8163 | Val Loss: 0.6531 | Val Acc: 0.8010
# Epoch 193 | Train Loss: 0.5770 | Train Acc: 0.8140 | Val Loss: 0.6544 | Val Acc: 0.7973
# Epoch 194 | Train Loss: 0.5715 | Train Acc: 0.8163 | Val Loss: 0.6527 | Val Acc: 0.7985
# Epoch 195 | Train Loss: 0.5749 | Train Acc: 0.8112 | Val Loss: 0.6512 | Val Acc: 0.7998
# Epoch 196 | Train Loss: 0.5780 | Train Acc: 0.8102 | Val Loss: 0.6498 | Val Acc: 0.8022
# Epoch 197 | Train Loss: 0.5727 | Train Acc: 0.8149 | Val Loss: 0.6487 | Val Acc: 0.8022
# Epoch 198 | Train Loss: 0.5747 | Train Acc: 0.8141 | Val Loss: 0.6480 | Val Acc: 0.8010
# Epoch 199 | Train Loss: 0.5719 | Train Acc: 0.8161 | Val Loss: 0.6476 | Val Acc: 0.8010
# Epoch 200 | Train Loss: 0.5847 | Train Acc: 0.8084 | Val Loss: 0.6468 | Val Acc: 0.8010
# Best GAT model saved to 'best_GAT.pt'
# Training GCN with best hyperparameters...
# Epoch 001 | Train Loss: 2.5375 | Train Acc: 0.1070 | Val Loss: 2.2838 | Val Acc: 0.3582
# Epoch 002 | Train Loss: 2.2188 | Train Acc: 0.2674 | Val Loss: 2.2601 | Val Acc: 0.4092
# Epoch 003 | Train Loss: 2.0637 | Train Acc: 0.3728 | Val Loss: 2.2318 | Val Acc: 0.4291
# Epoch 004 | Train Loss: 1.9854 | Train Acc: 0.3778 | Val Loss: 2.2095 | Val Acc: 0.4764
# Epoch 005 | Train Loss: 1.9278 | Train Acc: 0.3850 | Val Loss: 2.1902 | Val Acc: 0.5087
# Epoch 006 | Train Loss: 1.8012 | Train Acc: 0.4131 | Val Loss: 2.1699 | Val Acc: 0.5187
# Epoch 007 | Train Loss: 1.7634 | Train Acc: 0.4442 | Val Loss: 2.1445 | Val Acc: 0.5323
# Epoch 008 | Train Loss: 1.7358 | Train Acc: 0.4585 | Val Loss: 2.1177 | Val Acc: 0.5323
# Epoch 009 | Train Loss: 1.6614 | Train Acc: 0.4792 | Val Loss: 2.0915 | Val Acc: 0.5361
# Epoch 010 | Train Loss: 1.5932 | Train Acc: 0.5010 | Val Loss: 2.0661 | Val Acc: 0.5560
# Epoch 011 | Train Loss: 1.5261 | Train Acc: 0.5446 | Val Loss: 2.0399 | Val Acc: 0.5659
# Epoch 012 | Train Loss: 1.5065 | Train Acc: 0.5453 | Val Loss: 2.0115 | Val Acc: 0.5634
# Epoch 013 | Train Loss: 1.4553 | Train Acc: 0.5668 | Val Loss: 1.9817 | Val Acc: 0.5609
# Epoch 014 | Train Loss: 1.4309 | Train Acc: 0.5825 | Val Loss: 1.9473 | Val Acc: 0.5697
# Epoch 015 | Train Loss: 1.4087 | Train Acc: 0.5920 | Val Loss: 1.9109 | Val Acc: 0.5709
# Epoch 016 | Train Loss: 1.3724 | Train Acc: 0.6027 | Val Loss: 1.8744 | Val Acc: 0.5585
# Epoch 017 | Train Loss: 1.3471 | Train Acc: 0.5993 | Val Loss: 1.8376 | Val Acc: 0.5597
# Epoch 018 | Train Loss: 1.3219 | Train Acc: 0.5998 | Val Loss: 1.8003 | Val Acc: 0.5634
# Epoch 019 | Train Loss: 1.2821 | Train Acc: 0.6041 | Val Loss: 1.7628 | Val Acc: 0.5697
# Epoch 020 | Train Loss: 1.2538 | Train Acc: 0.6055 | Val Loss: 1.7249 | Val Acc: 0.5821
# Epoch 021 | Train Loss: 1.2175 | Train Acc: 0.6135 | Val Loss: 1.6860 | Val Acc: 0.5858
# Epoch 022 | Train Loss: 1.2052 | Train Acc: 0.6124 | Val Loss: 1.6495 | Val Acc: 0.6007
# Epoch 023 | Train Loss: 1.1857 | Train Acc: 0.6169 | Val Loss: 1.6132 | Val Acc: 0.6095
# Epoch 024 | Train Loss: 1.1654 | Train Acc: 0.6247 | Val Loss: 1.5767 | Val Acc: 0.6057
# Epoch 025 | Train Loss: 1.1387 | Train Acc: 0.6362 | Val Loss: 1.5392 | Val Acc: 0.6082
# Epoch 026 | Train Loss: 1.1329 | Train Acc: 0.6340 | Val Loss: 1.5054 | Val Acc: 0.6206
# Epoch 027 | Train Loss: 1.1154 | Train Acc: 0.6402 | Val Loss: 1.4594 | Val Acc: 0.6343
# Epoch 028 | Train Loss: 1.0856 | Train Acc: 0.6590 | Val Loss: 1.4196 | Val Acc: 0.6405
# Epoch 029 | Train Loss: 1.0681 | Train Acc: 0.6620 | Val Loss: 1.3846 | Val Acc: 0.6555
# Epoch 030 | Train Loss: 1.0533 | Train Acc: 0.6653 | Val Loss: 1.3499 | Val Acc: 0.6592
# Epoch 031 | Train Loss: 1.0453 | Train Acc: 0.6674 | Val Loss: 1.3162 | Val Acc: 0.6629
# Epoch 032 | Train Loss: 1.0300 | Train Acc: 0.6701 | Val Loss: 1.2890 | Val Acc: 0.6617
# Epoch 033 | Train Loss: 1.0130 | Train Acc: 0.6797 | Val Loss: 1.2524 | Val Acc: 0.6791
# Epoch 034 | Train Loss: 0.9969 | Train Acc: 0.6842 | Val Loss: 1.2228 | Val Acc: 0.6853
# Epoch 035 | Train Loss: 0.9847 | Train Acc: 0.6872 | Val Loss: 1.1937 | Val Acc: 0.6903
# Epoch 036 | Train Loss: 0.9737 | Train Acc: 0.6898 | Val Loss: 1.1733 | Val Acc: 0.6891
# Epoch 037 | Train Loss: 0.9414 | Train Acc: 0.7037 | Val Loss: 1.1566 | Val Acc: 0.6791
# Epoch 038 | Train Loss: 0.9375 | Train Acc: 0.7087 | Val Loss: 1.1378 | Val Acc: 0.6816
# Epoch 039 | Train Loss: 0.9364 | Train Acc: 0.7107 | Val Loss: 1.1133 | Val Acc: 0.6915
# Epoch 040 | Train Loss: 0.9330 | Train Acc: 0.7059 | Val Loss: 1.0936 | Val Acc: 0.6928
# Epoch 041 | Train Loss: 0.9098 | Train Acc: 0.7155 | Val Loss: 1.0682 | Val Acc: 0.6978
# Epoch 042 | Train Loss: 0.9109 | Train Acc: 0.7127 | Val Loss: 1.0533 | Val Acc: 0.7002
# Epoch 043 | Train Loss: 0.8886 | Train Acc: 0.7191 | Val Loss: 1.0339 | Val Acc: 0.7127
# Epoch 044 | Train Loss: 0.8869 | Train Acc: 0.7241 | Val Loss: 1.0106 | Val Acc: 0.7164
# Epoch 045 | Train Loss: 0.8791 | Train Acc: 0.7253 | Val Loss: 0.9961 | Val Acc: 0.7139
# Epoch 046 | Train Loss: 0.8633 | Train Acc: 0.7348 | Val Loss: 0.9784 | Val Acc: 0.7201
# Epoch 047 | Train Loss: 0.8578 | Train Acc: 0.7306 | Val Loss: 0.9559 | Val Acc: 0.7264
# Epoch 048 | Train Loss: 0.8552 | Train Acc: 0.7281 | Val Loss: 0.9425 | Val Acc: 0.7139
# Epoch 049 | Train Loss: 0.8252 | Train Acc: 0.7354 | Val Loss: 0.9297 | Val Acc: 0.7226
# Epoch 050 | Train Loss: 0.8400 | Train Acc: 0.7317 | Val Loss: 0.9177 | Val Acc: 0.7251
# Epoch 051 | Train Loss: 0.8307 | Train Acc: 0.7331 | Val Loss: 0.9176 | Val Acc: 0.7164
# Epoch 052 | Train Loss: 0.8182 | Train Acc: 0.7329 | Val Loss: 0.9152 | Val Acc: 0.7139
# Epoch 053 | Train Loss: 0.8256 | Train Acc: 0.7438 | Val Loss: 0.9073 | Val Acc: 0.7264
# Epoch 054 | Train Loss: 0.8209 | Train Acc: 0.7434 | Val Loss: 0.8826 | Val Acc: 0.7376
# Epoch 055 | Train Loss: 0.8183 | Train Acc: 0.7406 | Val Loss: 0.8854 | Val Acc: 0.7338
# Epoch 056 | Train Loss: 0.8223 | Train Acc: 0.7458 | Val Loss: 0.8698 | Val Acc: 0.7313
# Epoch 057 | Train Loss: 0.8110 | Train Acc: 0.7421 | Val Loss: 0.8655 | Val Acc: 0.7351
# Epoch 058 | Train Loss: 0.8067 | Train Acc: 0.7462 | Val Loss: 0.8626 | Val Acc: 0.7376
# Epoch 059 | Train Loss: 0.8010 | Train Acc: 0.7500 | Val Loss: 0.8448 | Val Acc: 0.7450
# Epoch 060 | Train Loss: 0.7891 | Train Acc: 0.7460 | Val Loss: 0.8365 | Val Acc: 0.7475
# Epoch 061 | Train Loss: 0.7808 | Train Acc: 0.7533 | Val Loss: 0.8791 | Val Acc: 0.7363
# Epoch 062 | Train Loss: 0.7962 | Train Acc: 0.7462 | Val Loss: 0.8523 | Val Acc: 0.7550
# Epoch 063 | Train Loss: 0.7926 | Train Acc: 0.7465 | Val Loss: 0.8599 | Val Acc: 0.7413
# Epoch 064 | Train Loss: 0.7864 | Train Acc: 0.7533 | Val Loss: 0.8384 | Val Acc: 0.7413
# Epoch 065 | Train Loss: 0.7854 | Train Acc: 0.7407 | Val Loss: 0.8381 | Val Acc: 0.7413
# Epoch 066 | Train Loss: 0.7928 | Train Acc: 0.7524 | Val Loss: 0.8576 | Val Acc: 0.7400
# Epoch 067 | Train Loss: 0.7773 | Train Acc: 0.7524 | Val Loss: 0.8204 | Val Acc: 0.7463
# Epoch 068 | Train Loss: 0.7718 | Train Acc: 0.7556 | Val Loss: 0.8159 | Val Acc: 0.7438
# Epoch 069 | Train Loss: 0.7661 | Train Acc: 0.7592 | Val Loss: 0.8091 | Val Acc: 0.7450
# Epoch 070 | Train Loss: 0.7574 | Train Acc: 0.7563 | Val Loss: 0.7981 | Val Acc: 0.7475
# Epoch 071 | Train Loss: 0.7521 | Train Acc: 0.7578 | Val Loss: 0.8054 | Val Acc: 0.7550
# Epoch 072 | Train Loss: 0.7558 | Train Acc: 0.7549 | Val Loss: 0.8015 | Val Acc: 0.7562
# Epoch 073 | Train Loss: 0.7430 | Train Acc: 0.7581 | Val Loss: 0.7966 | Val Acc: 0.7587
# Epoch 074 | Train Loss: 0.7353 | Train Acc: 0.7615 | Val Loss: 0.7965 | Val Acc: 0.7537
# Epoch 075 | Train Loss: 0.7459 | Train Acc: 0.7586 | Val Loss: 0.7877 | Val Acc: 0.7637
# Epoch 076 | Train Loss: 0.7311 | Train Acc: 0.7689 | Val Loss: 0.7819 | Val Acc: 0.7600
# Epoch 077 | Train Loss: 0.7305 | Train Acc: 0.7653 | Val Loss: 0.7926 | Val Acc: 0.7562
# Epoch 078 | Train Loss: 0.7382 | Train Acc: 0.7731 | Val Loss: 0.7906 | Val Acc: 0.7550
# Epoch 079 | Train Loss: 0.7385 | Train Acc: 0.7636 | Val Loss: 0.7742 | Val Acc: 0.7575
# Epoch 080 | Train Loss: 0.7173 | Train Acc: 0.7695 | Val Loss: 0.7929 | Val Acc: 0.7587
# Epoch 081 | Train Loss: 0.7435 | Train Acc: 0.7704 | Val Loss: 0.7840 | Val Acc: 0.7612
# Epoch 082 | Train Loss: 0.7263 | Train Acc: 0.7741 | Val Loss: 0.7761 | Val Acc: 0.7587
# Epoch 083 | Train Loss: 0.7157 | Train Acc: 0.7760 | Val Loss: 0.7644 | Val Acc: 0.7649
# Epoch 084 | Train Loss: 0.7072 | Train Acc: 0.7774 | Val Loss: 0.7609 | Val Acc: 0.7687
# Epoch 085 | Train Loss: 0.7223 | Train Acc: 0.7704 | Val Loss: 0.7648 | Val Acc: 0.7662
# Epoch 086 | Train Loss: 0.7183 | Train Acc: 0.7703 | Val Loss: 0.7656 | Val Acc: 0.7662
# Epoch 087 | Train Loss: 0.7082 | Train Acc: 0.7738 | Val Loss: 0.7574 | Val Acc: 0.7649
# Epoch 088 | Train Loss: 0.7112 | Train Acc: 0.7768 | Val Loss: 0.7525 | Val Acc: 0.7724
# Epoch 089 | Train Loss: 0.7124 | Train Acc: 0.7676 | Val Loss: 0.7480 | Val Acc: 0.7674
# Epoch 090 | Train Loss: 0.7118 | Train Acc: 0.7667 | Val Loss: 0.7540 | Val Acc: 0.7687
# Epoch 091 | Train Loss: 0.7079 | Train Acc: 0.7732 | Val Loss: 0.7572 | Val Acc: 0.7624
# Epoch 092 | Train Loss: 0.7012 | Train Acc: 0.7790 | Val Loss: 0.7503 | Val Acc: 0.7674
# Epoch 093 | Train Loss: 0.7026 | Train Acc: 0.7724 | Val Loss: 0.7506 | Val Acc: 0.7612
# Epoch 094 | Train Loss: 0.6987 | Train Acc: 0.7723 | Val Loss: 0.7395 | Val Acc: 0.7612
# Epoch 095 | Train Loss: 0.6871 | Train Acc: 0.7780 | Val Loss: 0.7440 | Val Acc: 0.7637
# Epoch 096 | Train Loss: 0.7058 | Train Acc: 0.7782 | Val Loss: 0.7404 | Val Acc: 0.7687
# Epoch 097 | Train Loss: 0.6897 | Train Acc: 0.7760 | Val Loss: 0.7445 | Val Acc: 0.7649
# Epoch 098 | Train Loss: 0.6864 | Train Acc: 0.7847 | Val Loss: 0.7357 | Val Acc: 0.7699
# Epoch 099 | Train Loss: 0.7041 | Train Acc: 0.7749 | Val Loss: 0.7368 | Val Acc: 0.7699
# Epoch 100 | Train Loss: 0.6864 | Train Acc: 0.7835 | Val Loss: 0.7359 | Val Acc: 0.7699
# Epoch 101 | Train Loss: 0.6906 | Train Acc: 0.7804 | Val Loss: 0.7305 | Val Acc: 0.7736
# Epoch 102 | Train Loss: 0.6809 | Train Acc: 0.7863 | Val Loss: 0.7286 | Val Acc: 0.7736
# Epoch 103 | Train Loss: 0.6874 | Train Acc: 0.7793 | Val Loss: 0.7281 | Val Acc: 0.7736
# Epoch 104 | Train Loss: 0.6808 | Train Acc: 0.7816 | Val Loss: 0.7390 | Val Acc: 0.7749
# Epoch 105 | Train Loss: 0.6790 | Train Acc: 0.7866 | Val Loss: 0.7409 | Val Acc: 0.7687
# Epoch 106 | Train Loss: 0.6744 | Train Acc: 0.7923 | Val Loss: 0.7448 | Val Acc: 0.7724
# Epoch 107 | Train Loss: 0.6885 | Train Acc: 0.7818 | Val Loss: 0.7627 | Val Acc: 0.7649
# Epoch 108 | Train Loss: 0.6867 | Train Acc: 0.7783 | Val Loss: 0.7687 | Val Acc: 0.7637
# Epoch 109 | Train Loss: 0.6982 | Train Acc: 0.7765 | Val Loss: 0.7440 | Val Acc: 0.7687
# Epoch 110 | Train Loss: 0.6856 | Train Acc: 0.7773 | Val Loss: 0.7329 | Val Acc: 0.7699
# Epoch 111 | Train Loss: 0.6722 | Train Acc: 0.7822 | Val Loss: 0.7267 | Val Acc: 0.7761
# Epoch 112 | Train Loss: 0.6727 | Train Acc: 0.7822 | Val Loss: 0.7332 | Val Acc: 0.7786
# Epoch 113 | Train Loss: 0.6674 | Train Acc: 0.7849 | Val Loss: 0.7253 | Val Acc: 0.7799
# Epoch 114 | Train Loss: 0.6759 | Train Acc: 0.7827 | Val Loss: 0.7207 | Val Acc: 0.7774
# Epoch 115 | Train Loss: 0.6703 | Train Acc: 0.7838 | Val Loss: 0.7188 | Val Acc: 0.7699
# Epoch 116 | Train Loss: 0.6648 | Train Acc: 0.7897 | Val Loss: 0.7263 | Val Acc: 0.7724
# Epoch 117 | Train Loss: 0.6706 | Train Acc: 0.7815 | Val Loss: 0.7139 | Val Acc: 0.7774
# Epoch 118 | Train Loss: 0.6650 | Train Acc: 0.7835 | Val Loss: 0.7097 | Val Acc: 0.7774
# Epoch 119 | Train Loss: 0.6674 | Train Acc: 0.7874 | Val Loss: 0.7067 | Val Acc: 0.7761
# Epoch 120 | Train Loss: 0.6611 | Train Acc: 0.7885 | Val Loss: 0.7087 | Val Acc: 0.7724
# Epoch 121 | Train Loss: 0.6671 | Train Acc: 0.7863 | Val Loss: 0.7086 | Val Acc: 0.7749
# Epoch 122 | Train Loss: 0.6572 | Train Acc: 0.7869 | Val Loss: 0.7128 | Val Acc: 0.7736
# Epoch 123 | Train Loss: 0.6537 | Train Acc: 0.7905 | Val Loss: 0.7158 | Val Acc: 0.7761
# Epoch 124 | Train Loss: 0.6508 | Train Acc: 0.7922 | Val Loss: 0.7095 | Val Acc: 0.7761
# Epoch 125 | Train Loss: 0.6524 | Train Acc: 0.7875 | Val Loss: 0.7061 | Val Acc: 0.7786
# Epoch 126 | Train Loss: 0.6533 | Train Acc: 0.7881 | Val Loss: 0.7087 | Val Acc: 0.7786
# Epoch 127 | Train Loss: 0.6484 | Train Acc: 0.7909 | Val Loss: 0.7068 | Val Acc: 0.7761
# Epoch 128 | Train Loss: 0.6537 | Train Acc: 0.7891 | Val Loss: 0.7056 | Val Acc: 0.7823
# Epoch 129 | Train Loss: 0.6560 | Train Acc: 0.7880 | Val Loss: 0.7039 | Val Acc: 0.7761
# Epoch 130 | Train Loss: 0.6528 | Train Acc: 0.7874 | Val Loss: 0.6991 | Val Acc: 0.7811
# Epoch 131 | Train Loss: 0.6515 | Train Acc: 0.7903 | Val Loss: 0.6982 | Val Acc: 0.7799
# Epoch 132 | Train Loss: 0.6607 | Train Acc: 0.7881 | Val Loss: 0.6965 | Val Acc: 0.7811
# Epoch 133 | Train Loss: 0.6473 | Train Acc: 0.7894 | Val Loss: 0.6971 | Val Acc: 0.7823
# Epoch 134 | Train Loss: 0.6508 | Train Acc: 0.7903 | Val Loss: 0.7017 | Val Acc: 0.7823
# Epoch 135 | Train Loss: 0.6437 | Train Acc: 0.7869 | Val Loss: 0.7073 | Val Acc: 0.7799
# Epoch 136 | Train Loss: 0.6486 | Train Acc: 0.7950 | Val Loss: 0.7065 | Val Acc: 0.7774
# Epoch 137 | Train Loss: 0.6537 | Train Acc: 0.7867 | Val Loss: 0.7011 | Val Acc: 0.7786
# Epoch 138 | Train Loss: 0.6503 | Train Acc: 0.7919 | Val Loss: 0.7009 | Val Acc: 0.7786
# Epoch 139 | Train Loss: 0.6493 | Train Acc: 0.7888 | Val Loss: 0.6997 | Val Acc: 0.7749
# Epoch 140 | Train Loss: 0.6418 | Train Acc: 0.7958 | Val Loss: 0.7006 | Val Acc: 0.7786
# Epoch 141 | Train Loss: 0.6424 | Train Acc: 0.7931 | Val Loss: 0.7032 | Val Acc: 0.7811
# Epoch 142 | Train Loss: 0.6482 | Train Acc: 0.7936 | Val Loss: 0.6999 | Val Acc: 0.7761
# Epoch 143 | Train Loss: 0.6378 | Train Acc: 0.8003 | Val Loss: 0.6941 | Val Acc: 0.7799
# Epoch 144 | Train Loss: 0.6416 | Train Acc: 0.7945 | Val Loss: 0.6908 | Val Acc: 0.7761
# Epoch 145 | Train Loss: 0.6350 | Train Acc: 0.7975 | Val Loss: 0.6892 | Val Acc: 0.7749
# Epoch 146 | Train Loss: 0.6397 | Train Acc: 0.7976 | Val Loss: 0.6873 | Val Acc: 0.7761
# Epoch 147 | Train Loss: 0.6385 | Train Acc: 0.7955 | Val Loss: 0.6874 | Val Acc: 0.7774
# Epoch 148 | Train Loss: 0.6354 | Train Acc: 0.7958 | Val Loss: 0.6890 | Val Acc: 0.7799
# Epoch 149 | Train Loss: 0.6431 | Train Acc: 0.7923 | Val Loss: 0.6897 | Val Acc: 0.7786
# Epoch 150 | Train Loss: 0.6327 | Train Acc: 0.7959 | Val Loss: 0.6899 | Val Acc: 0.7786
# Epoch 151 | Train Loss: 0.6384 | Train Acc: 0.7964 | Val Loss: 0.6879 | Val Acc: 0.7799
# Epoch 152 | Train Loss: 0.6400 | Train Acc: 0.7942 | Val Loss: 0.6863 | Val Acc: 0.7786
# Epoch 153 | Train Loss: 0.6355 | Train Acc: 0.7984 | Val Loss: 0.6863 | Val Acc: 0.7786
# Epoch 154 | Train Loss: 0.6362 | Train Acc: 0.7978 | Val Loss: 0.6873 | Val Acc: 0.7786
# Epoch 155 | Train Loss: 0.6389 | Train Acc: 0.7930 | Val Loss: 0.6861 | Val Acc: 0.7811
# Epoch 156 | Train Loss: 0.6263 | Train Acc: 0.7978 | Val Loss: 0.6859 | Val Acc: 0.7823
# Epoch 157 | Train Loss: 0.6339 | Train Acc: 0.8025 | Val Loss: 0.6866 | Val Acc: 0.7799
# Epoch 158 | Train Loss: 0.6292 | Train Acc: 0.7975 | Val Loss: 0.6858 | Val Acc: 0.7823
# Epoch 159 | Train Loss: 0.6304 | Train Acc: 0.7967 | Val Loss: 0.6857 | Val Acc: 0.7811
# Epoch 160 | Train Loss: 0.6293 | Train Acc: 0.8031 | Val Loss: 0.6855 | Val Acc: 0.7811
# Epoch 161 | Train Loss: 0.6309 | Train Acc: 0.8012 | Val Loss: 0.6852 | Val Acc: 0.7823
# Epoch 162 | Train Loss: 0.6354 | Train Acc: 0.7967 | Val Loss: 0.6850 | Val Acc: 0.7811
# Epoch 163 | Train Loss: 0.6285 | Train Acc: 0.7972 | Val Loss: 0.6846 | Val Acc: 0.7799
# Epoch 164 | Train Loss: 0.6377 | Train Acc: 0.7959 | Val Loss: 0.6837 | Val Acc: 0.7799
# Epoch 165 | Train Loss: 0.6324 | Train Acc: 0.7961 | Val Loss: 0.6835 | Val Acc: 0.7799
# Epoch 166 | Train Loss: 0.6305 | Train Acc: 0.7964 | Val Loss: 0.6842 | Val Acc: 0.7823
# Epoch 167 | Train Loss: 0.6266 | Train Acc: 0.7987 | Val Loss: 0.6844 | Val Acc: 0.7861
# Epoch 168 | Train Loss: 0.6286 | Train Acc: 0.7979 | Val Loss: 0.6839 | Val Acc: 0.7848
# Epoch 169 | Train Loss: 0.6281 | Train Acc: 0.7964 | Val Loss: 0.6816 | Val Acc: 0.7823
# Epoch 170 | Train Loss: 0.6248 | Train Acc: 0.7947 | Val Loss: 0.6807 | Val Acc: 0.7848
# Epoch 171 | Train Loss: 0.6322 | Train Acc: 0.7976 | Val Loss: 0.6811 | Val Acc: 0.7836
# Epoch 172 | Train Loss: 0.6350 | Train Acc: 0.7889 | Val Loss: 0.6831 | Val Acc: 0.7836
# Epoch 173 | Train Loss: 0.6198 | Train Acc: 0.8039 | Val Loss: 0.6843 | Val Acc: 0.7848
# Epoch 174 | Train Loss: 0.6241 | Train Acc: 0.8029 | Val Loss: 0.6880 | Val Acc: 0.7811
# Epoch 175 | Train Loss: 0.6221 | Train Acc: 0.7962 | Val Loss: 0.6868 | Val Acc: 0.7786
# Epoch 176 | Train Loss: 0.6327 | Train Acc: 0.7950 | Val Loss: 0.6840 | Val Acc: 0.7799
# Epoch 177 | Train Loss: 0.6258 | Train Acc: 0.7962 | Val Loss: 0.6821 | Val Acc: 0.7823
# Epoch 178 | Train Loss: 0.6238 | Train Acc: 0.8031 | Val Loss: 0.6811 | Val Acc: 0.7848
# Epoch 179 | Train Loss: 0.6203 | Train Acc: 0.7976 | Val Loss: 0.6816 | Val Acc: 0.7823
# Epoch 180 | Train Loss: 0.6230 | Train Acc: 0.7987 | Val Loss: 0.6821 | Val Acc: 0.7823
# Epoch 181 | Train Loss: 0.6249 | Train Acc: 0.7973 | Val Loss: 0.6822 | Val Acc: 0.7811
# Epoch 182 | Train Loss: 0.6222 | Train Acc: 0.7965 | Val Loss: 0.6820 | Val Acc: 0.7811
# Epoch 183 | Train Loss: 0.6251 | Train Acc: 0.8020 | Val Loss: 0.6813 | Val Acc: 0.7811
# Epoch 184 | Train Loss: 0.6201 | Train Acc: 0.7990 | Val Loss: 0.6804 | Val Acc: 0.7823
# Epoch 185 | Train Loss: 0.6195 | Train Acc: 0.8042 | Val Loss: 0.6795 | Val Acc: 0.7811
# Epoch 186 | Train Loss: 0.6210 | Train Acc: 0.8018 | Val Loss: 0.6787 | Val Acc: 0.7811
# Epoch 187 | Train Loss: 0.6257 | Train Acc: 0.7981 | Val Loss: 0.6781 | Val Acc: 0.7811
# Epoch 188 | Train Loss: 0.6232 | Train Acc: 0.7965 | Val Loss: 0.6777 | Val Acc: 0.7811
# Epoch 189 | Train Loss: 0.6203 | Train Acc: 0.7990 | Val Loss: 0.6775 | Val Acc: 0.7811
# Epoch 190 | Train Loss: 0.6208 | Train Acc: 0.7998 | Val Loss: 0.6776 | Val Acc: 0.7811
# Epoch 191 | Train Loss: 0.6188 | Train Acc: 0.8031 | Val Loss: 0.6777 | Val Acc: 0.7811
# Epoch 192 | Train Loss: 0.6320 | Train Acc: 0.7944 | Val Loss: 0.6778 | Val Acc: 0.7811
# Epoch 193 | Train Loss: 0.6199 | Train Acc: 0.7998 | Val Loss: 0.6779 | Val Acc: 0.7811
# Epoch 194 | Train Loss: 0.6226 | Train Acc: 0.8023 | Val Loss: 0.6780 | Val Acc: 0.7811
# Epoch 195 | Train Loss: 0.6270 | Train Acc: 0.7986 | Val Loss: 0.6781 | Val Acc: 0.7823
# Epoch 196 | Train Loss: 0.6196 | Train Acc: 0.8031 | Val Loss: 0.6780 | Val Acc: 0.7823
# Epoch 197 | Train Loss: 0.6251 | Train Acc: 0.8000 | Val Loss: 0.6780 | Val Acc: 0.7823
# Epoch 198 | Train Loss: 0.6227 | Train Acc: 0.7997 | Val Loss: 0.6778 | Val Acc: 0.7823
# Epoch 199 | Train Loss: 0.6291 | Train Acc: 0.7995 | Val Loss: 0.6777 | Val Acc: 0.7823
# Epoch 200 | Train Loss: 0.6167 | Train Acc: 0.8018 | Val Loss: 0.6776 | Val Acc: 0.7823
# Best GCN model saved to 'best_GCN.pt'

# %%
import torch

data = torch.load('all_graph_data/processed/data.pt', weights_only=False)
print(data)
# Out:
# Data(x=[8037, 1024], edge_index=[2, 120567], y=[8037], train_mask=[8037], val_mask=[8037], test_mask=[8037])

# %%
import pandas as pd

# Load metadata
metadata = pd.read_csv('nepali_music_metadata.csv')

# Create a mapping from class index to class name
class_mapping = dict(zip(metadata['class_id'], metadata['class_name']))

# %%
def predict_new_audio(audio_path):
    """
    Predict the class of a new audio file using the trained GNN model.
    
    Args:
        audio_path (str): Path to the audio file (30s WAV format).
    
    Returns:
        str: Predicted class name.
    """
    # Load YAMNet model (only once, cache it)
    if 'yamnet_model' not in globals():
        global yamnet_model
        yamnet_model = hub.load('https://tfhub.dev/google/yamnet/1')
    
    # Load GNN model
    model = GAT(1024, 10) if MODEL_TYPE == 'gat' else GCN(1024, 10)
    model.load_state_dict(torch.load('best_GAT.pt'))
    model = model.to(DEVICE).eval()
    
    # Load existing data and normalization parameters
    data = torch.load(osp.join('all_graph_data/processed', 'data.pt'))
    norm_params = torch.load(osp.join('all_graph_data/processed', 'norm_params.pt'))
    
    try:
        # Step 1: Load and preprocess audio
        audio, sr = librosa.load(audio_path, sr=None, mono=True)
        if sr != 16000:  # Resample to YAMNet's expected sample rate
            audio = resampy.resample(audio, sr, 16000)
        
        # Step 2: Extract YAMNet features
        _, yamnet_embeddings, _ = yamnet_model(audio)
        new_feature = torch.tensor(np.mean(yamnet_embeddings.numpy(), axis=0), dtype=torch.float32)
        
        # Step 3: Normalize features using training data statistics
        new_feature = (new_feature - norm_params['min']) / (norm_params['max'] - norm_params['min'] + 1e-8)
        
        # Step 4: Move all tensors to the same device
        data.x = data.x.to(DEVICE)  # Move graph features to the same device as the model
        new_feature = new_feature.to(DEVICE)  # Ensure new feature is on the same device
        
        # Step 5: Create extended graph
        combined_features = torch.cat([data.x, new_feature.unsqueeze(0)])
        edge_index = knn_graph(combined_features, k=K)
        
        # Step 6: Make prediction
        with torch.no_grad():
            out = model(combined_features, edge_index)
            predicted_class_index = out[-1].argmax().item()
        
        # Step 7: Map class index to class name
        predicted_class_name = class_mapping.get(predicted_class_index, "Unknown")
        return predicted_class_name
    
    except Exception as e:
        print(f"Error processing {audio_path}: {str(e)}")
        return None  # Return None if inference fails

# %%
# Cell 7: Example Usage of Inference Function
audio_path = "sakela_test_023.wav"  # Replace with your audio file path
predicted_class = predict_new_audio(audio_path)

if predicted_class is not None:
    print(f"Predicted class index: {predicted_class}")
else:
    print("Failed to process the audio file.")
# Out:
# /tmp/ipykernel_13251/3477632411.py:18: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('best_GAT.pt'))
# /tmp/ipykernel_13251/3477632411.py:22: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load(osp.join('all_graph_data/processed', 'data.pt'))
# /tmp/ipykernel_13251/3477632411.py:23: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   norm_params = torch.load(osp.join('all_graph_data/processed', 'norm_params.pt'))
# Predicted class index: sakela
